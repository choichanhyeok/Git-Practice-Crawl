# %%
f = open('UserTextList_after_process.txt', 'a', encoding='UTF-8')
    
with open ('DefUserText.txt', 'r', encoding='UTF8') as fr:
    data_list = []
    for line in fr:
        print (line)
        data_list.append(line)
    my_set = set(data_list)
    data_list = list(my_set)
    f.writelines(data_list)
    f.close()
    fr.close()
# Out:
# syscom2020
#
# •
#
#
#
#
#
#
#
#
#
# 120
#
# syscom2020
#
# "나 리부트 #학습여행"
#
#
#
# #4차산업혁명시대 필수능력인 다양성 갖춘 융복합 문제해결 위한 나의 잠재능력 발견은 "지식"을 "지혜"로 전환하는 #현장학습여행으로 하세요.
#
#
#
# 인공지능( #AI ) 시대 불안한 #청소년 #감성치유 #체험학습 시간여행
#
#
#
# - #디지털시대 자신소개를 자신있게 하기 위한 다양한 현장체험 프로젝트 "슬기로운행복꿈채우기"
#
#
#
# - 21C 인공지능(AI) 그리고 로봇으로부터 나를 위한 진정한 인간 감성이해 및 윤리적사고 함양 인간학, 창의력, 이해력, 상상력, 논리적인 비판적사고, 상황판단, 종합적 사고력 체험 프로그램.
#
#
#
# - 인공지능(AI). 로봇으로부터 진정한 사람의 직업을 지키는 사람을 육성하는 [다양성인식(다양한 꿈 체험)➡️자유학기제➡️고교학점제➡️수능➡️취업 준비➡️💯세 시대)] 미래설계도 만드는 슬기로운 행복 꿈 채우기 프로젝트!!!!
#
#
#
# ...
