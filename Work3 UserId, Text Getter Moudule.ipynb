# %% [markdown]
# # Work3: UserId, Text Getter Module

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time
#######################################################################################################################
# 셀레니움 셋업 #
#######################################################################################################################
chromedriver = 'chromedriver'           # 크롬 드라이버 상대경로로 할당 #
driver = webdriver.Chrome(chromedriver) # 할당 된 크롬 드라이버를 dirver에 할당 # 

driver.get('https://www.instagram.com/') # 인스타 주소를 driver 올려준다 #
SCROLL_PAUSE_SEC = 2
########################################################################################################################
# 로그인 #
########################################################################################################################
# 인스타 계정 Login 정보 #
username = '01077741874'
password = 'slqlrjf12#$'
# 로그인 입력 창 및 버튼 Xapth 주소 #
InEmail_id = "//*[@id='loginForm']/div/div[1]/div/label/input"
InPassword_id = "//*[@id='loginForm']/div/div[2]/div/label/input"
loginButton = "//*[@id='loginForm']/div/div[3]/button"
# Css 예시 #
#id_data = driver.find_element_by_css_selector('#loginForm > div > div:nth-child(1) > div > label > input')

# 4초간 기다린 후 각각의 로그인 필드들을 동기화 해준다 #
id_field = WebDriverWait(driver, 4).until(EC.presence_of_element_located((By.XPATH, InEmail_id))) # ID INPUT 지정 #
pw_field = WebDriverWait(driver, 4).until(EC.presence_of_element_located((By.XPATH, InPassword_id))) # 비밀번호 INPUT 지정 #
loginButton_tag = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, loginButton))) # Login 지정 #

# id, 비밀번호를 입력 후 로그인 버튼을 누른다 # 
id_field.clear() # ID 칸 비우기 #
id_field.send_keys(username) # ID 입력: ID에 담긴 데이터 전달 #
pw_field.clear() # 비밀번호 칸 비우기 #
pw_field.send_keys(password) # 비밀번호 입력: password에 담긴 데이터 전달 #
loginButton_tag.click() # 로그인 버튼 클릭 #

#######################################################################################################################
# 본격 크롤링 #
time.sleep(4)
#######################################################################################################################
# 시작 버튼 클릭 #
# 인스타 시작시에 귀찮게 구는 팝업창 없애기 위한 부분 #
startButton = "//*[@id='react-root']/section/main/div/div/div/div/button"
startButton_Key = driver.find_element_by_xpath(startButton)
startButton_Key.click() # 첫 번째 팝업 버튼 매핑 후 클릭 해주는 구문 #
time.sleep(2)
startButton2 = "/html/body/div[4]/div/div/div/div[3]/button[2]"
startButton_Key2 = driver.find_element_by_xpath(startButton2)
startButton_Key2.click() # 두 번째 팝업 버튼 매핑 후 클릭 해주는 구문 #

itrurp = ['소개', '블로그', '채용 정보','도움말', 'API', '개인정보처리방침', '약관', '인기 계정', '해시태그', '위치' ]

# v1Nh3 kIKUG  _bz0w
f = open("DefUserName.txt", 'a', encoding='UTF-8') # 파일 쓰기를 위한 f 변수 할당 #
ft = open("DefUserText.txt", 'a', encoding='UTF-8') # 파일 쓰기를 위한 f 변수 할당 #
ftag = open("DefTagText.txt", 'a', encoding='UTF-8') 

with open("PostUrlSet2.txt", 'r') as fUrlList:
    UrlList = []
    for line in fUrlList:
        UrlList.append(line)

i = 0
# 각 게시글 접속 #
time.sleep(4)     # 더보기 버튼 Xpath 경로 저장 #
ShowMoreButton = "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul/li/div"
for url in UrlList:
    time.sleep(1)
    print(url.rstrip('\n'))
    print ("location.replace(\'"+ url.rstrip('\n') +"\')")
    driver.execute_script("location.replace(\'"+ url.rstrip('\n') +"\')")
    # driver.execute_script('location.href=' + "\'" + url + "\'")
    i += 1
    time.sleep(3)
    j = 0
    time.sleep(1)
    try:
        UserList = "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul"
        UserList_tag = driver.find_element_by_xpath(UserList)
        UserList_size = UserList_tag.find_elements_by_class_name('Mr508')
        length = len(UserList_size)
        a = list(range(length))
    except:
        a = list(range(1))
        pass
    
    try:
        # print ('길이: ' + str(UserList_tag))
        if (length > 8 ):
            ShowMoreButton_Tag = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, ShowMoreButton)))
            while True:   # 끝까지 스크롤 다운
                if (WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, ShowMoreButton)))):
                    ShowMoreButton_Tag.click()
                time.sleep(2)
                j += 1
                if j == 8:
                    break
    except TimeoutException:
        print("버튼없어!!")
    try:
        UserId_Cont = WebDriverWait(driver, 5).until(EC.presence_of_all_elements_located((By.TAG_NAME, 'a')))
    except:
        pass
    print(type(UserId_Cont))
    print(len(UserId_Cont)) 
    for x in range(len(UserId_Cont)):
        data = UserId_Cont[x].text
        f.write(data+"\n")
    try:
        UserText_Cont = WebDriverWait(driver, 5).until(EC.presence_of_all_elements_located((By.TAG_NAME, 'span')))
    except:
        pass
        
    for y in range(len(UserText_Cont)):
        data2 = UserText_Cont[y].text
        ft.write(data2+'\n')
    del UserId_Cont[:]
    del UserText_Cont[:]
# driver.execute_script("window.history.go(-1)")
f.close()
ft.close()
print("완벽 정상 작동")
driver.quit()
# Out:
# https://www.instagram.com/p/CJvFPmTnxdl/
# location.replace('https://www.instagram.com/p/CJvFPmTnxdl/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJtFeP9laPK/
# location.replace('https://www.instagram.com/p/CJtFeP9laPK/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CKLpePphaUr/
# location.replace('https://www.instagram.com/p/CKLpePphaUr/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJrHFCZFLiS/
# location.replace('https://www.instagram.com/p/CJrHFCZFLiS/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJeQbwWgxTA/
# location.replace('https://www.instagram.com/p/CJeQbwWgxTA/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CJqd-Ncg2Hw/
# location.replace('https://www.instagram.com/p/CJqd-Ncg2Hw/')
# <class 'list'>
# 24
# https://www.instagram.com/p/CKB0lV1DXxJ/
# location.replace('https://www.instagram.com/p/CKB0lV1DXxJ/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKEBwbdhzd-/
# location.replace('https://www.instagram.com/p/CKEBwbdhzd-/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJxv9sVHZxJ/
# location.replace('https://www.instagram.com/p/CJxv9sVHZxJ/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CIhvVPSp-IM/
# location.replace('https://www.instagram.com/p/CIhvVPSp-IM/')
# <class 'list'>
# 24
# https://www.instagram.com/p/CKBYQMRD_E4/
# location.replace('https://www.instagram.com/p/CKBYQMRD_E4/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CKAjRoTnXEY/
# location.replace('https://www.instagram.com/p/CKAjRoTnXEY/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJwpCoJneb8/
# location.replace('https://www.instagram.com/p/CJwpCoJneb8/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJkZlAklOH0/
# location.replace('https://www.instagram.com/p/CJkZlAklOH0/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJ7u_alpg3v/
# location.replace('https://www.instagram.com/p/CJ7u_alpg3v/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJvokYbFKcm/
# location.replace('https://www.instagram.com/p/CJvokYbFKcm/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ_yzBsjezX/
# location.replace('https://www.instagram.com/p/CJ_yzBsjezX/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJwMK61gSvH/
# location.replace('https://www.instagram.com/p/CJwMK61gSvH/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CKJOaIYHR4q/
# location.replace('https://www.instagram.com/p/CKJOaIYHR4q/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJuiElYBFDe/
# location.replace('https://www.instagram.com/p/CJuiElYBFDe/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJiyaO5lrhm/
# location.replace('https://www.instagram.com/p/CJiyaO5lrhm/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CKGTIhyFJ6w/
# location.replace('https://www.instagram.com/p/CKGTIhyFJ6w/')
# <class 'list'>
# 64
# https://www.instagram.com/p/CJn_K1dFPIC/
# location.replace('https://www.instagram.com/p/CJn_K1dFPIC/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJkpNEBlDUs/
# location.replace('https://www.instagram.com/p/CJkpNEBlDUs/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CKKtvVXF9bB/
# location.replace('https://www.instagram.com/p/CKKtvVXF9bB/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CJ7Mg0ks7o0/
# location.replace('https://www.instagram.com/p/CJ7Mg0ks7o0/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKB8JwYJkcK/
# location.replace('https://www.instagram.com/p/CKB8JwYJkcK/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKGUq5FFdym/
# location.replace('https://www.instagram.com/p/CKGUq5FFdym/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJ2CRfDM7Iw/
# location.replace('https://www.instagram.com/p/CJ2CRfDM7Iw/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJ0UDoUpSSE/
# location.replace('https://www.instagram.com/p/CJ0UDoUpSSE/')
# <class 'list'>
# 38
# https://www.instagram.com/p/CJnTlWvp4Gb/
# location.replace('https://www.instagram.com/p/CJnTlWvp4Gb/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CJgaUS4AUP9/
# location.replace('https://www.instagram.com/p/CJgaUS4AUP9/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJyL02rF2iF/
# location.replace('https://www.instagram.com/p/CJyL02rF2iF/')
# <class 'list'>
# 69
# https://www.instagram.com/p/CJ6AvOSlHQx/
# location.replace('https://www.instagram.com/p/CJ6AvOSlHQx/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJ3E3qTFK7C/
# location.replace('https://www.instagram.com/p/CJ3E3qTFK7C/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJojfyPBRuS/
# location.replace('https://www.instagram.com/p/CJojfyPBRuS/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJuytoQM7pE/
# location.replace('https://www.instagram.com/p/CJuytoQM7pE/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJyIPPHD3ca/
# location.replace('https://www.instagram.com/p/CJyIPPHD3ca/')
# <class 'list'>
# 25
# https://www.instagram.com/p/CJ97FqYF4vt/
# location.replace('https://www.instagram.com/p/CJ97FqYF4vt/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ0VS93ADBR/
# location.replace('https://www.instagram.com/p/CJ0VS93ADBR/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJvhxG-jc2m/
# location.replace('https://www.instagram.com/p/CJvhxG-jc2m/')
# <class 'list'>
# 39
# https://www.instagram.com/p/CKA1xwFHcsY/
# location.replace('https://www.instagram.com/p/CKA1xwFHcsY/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJpTCa3JWmI/
# location.replace('https://www.instagram.com/p/CJpTCa3JWmI/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJ01xeUlwA9/
# location.replace('https://www.instagram.com/p/CJ01xeUlwA9/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CKBriD5Fzph/
# location.replace('https://www.instagram.com/p/CKBriD5Fzph/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJoSyxcnjR6/
# location.replace('https://www.instagram.com/p/CJoSyxcnjR6/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CKBacj8JNPX/
# location.replace('https://www.instagram.com/p/CKBacj8JNPX/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKBzeD8F2z3/
# location.replace('https://www.instagram.com/p/CKBzeD8F2z3/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CKKxAmgFFNg/
# location.replace('https://www.instagram.com/p/CKKxAmgFFNg/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKEvYyEB223/
# location.replace('https://www.instagram.com/p/CKEvYyEB223/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CJnh0Bzldhi/
# location.replace('https://www.instagram.com/p/CJnh0Bzldhi/')
# 버튼없어!!
# <class 'list'>
# 90
# https://www.instagram.com/p/CI2-cdgBYL2/
# location.replace('https://www.instagram.com/p/CI2-cdgBYL2/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ3_JNKhBLp/
# location.replace('https://www.instagram.com/p/CJ3_JNKhBLp/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJqnYhrFB_y/
# location.replace('https://www.instagram.com/p/CJqnYhrFB_y/')
# <class 'list'>
# 70
# https://www.instagram.com/p/CJyhbxYFwnZ/
# location.replace('https://www.instagram.com/p/CJyhbxYFwnZ/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CKJL3SWFURu/
# location.replace('https://www.instagram.com/p/CKJL3SWFURu/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CKDMUGTlsEV/
# location.replace('https://www.instagram.com/p/CKDMUGTlsEV/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJhqE-6FTMi/
# location.replace('https://www.instagram.com/p/CJhqE-6FTMi/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJ_i32XnRvm/
# location.replace('https://www.instagram.com/p/CJ_i32XnRvm/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKBOnR5lfdt/
# location.replace('https://www.instagram.com/p/CKBOnR5lfdt/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CJxzFy5pHtt/
# location.replace('https://www.instagram.com/p/CJxzFy5pHtt/')
# <class 'list'>
# 148
# https://www.instagram.com/p/CKA3pX7ldg8/
# location.replace('https://www.instagram.com/p/CKA3pX7ldg8/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJnVbqhJ9vw/
# location.replace('https://www.instagram.com/p/CJnVbqhJ9vw/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJ1Ftd1Fuzz/
# location.replace('https://www.instagram.com/p/CJ1Ftd1Fuzz/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJ3aG87FfIH/
# location.replace('https://www.instagram.com/p/CJ3aG87FfIH/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJoMxyBF1TD/
# location.replace('https://www.instagram.com/p/CJoMxyBF1TD/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJ3plkIl3GB/
# location.replace('https://www.instagram.com/p/CJ3plkIl3GB/')
# <class 'list'>
# 21
# https://www.instagram.com/p/CJ-BQKSnvnn/
# location.replace('https://www.instagram.com/p/CJ-BQKSnvnn/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJyl_Nvs2-9/
# location.replace('https://www.instagram.com/p/CJyl_Nvs2-9/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJswJseFaqT/
# location.replace('https://www.instagram.com/p/CJswJseFaqT/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJpn7wdBNaN/
# location.replace('https://www.instagram.com/p/CJpn7wdBNaN/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJsXO68r4qi/
# location.replace('https://www.instagram.com/p/CJsXO68r4qi/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CKEdnYzlh_c/
# location.replace('https://www.instagram.com/p/CKEdnYzlh_c/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJ06lC9LDiK/
# location.replace('https://www.instagram.com/p/CJ06lC9LDiK/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJ0Bh1JlTiK/
# location.replace('https://www.instagram.com/p/CJ0Bh1JlTiK/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKDgFoih2cD/
# location.replace('https://www.instagram.com/p/CKDgFoih2cD/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJ4nk12ljuG/
# location.replace('https://www.instagram.com/p/CJ4nk12ljuG/')
# 버튼없어!!
# <class 'list'>
# 63
# https://www.instagram.com/p/CJqR3V9BKSQ/
# location.replace('https://www.instagram.com/p/CJqR3V9BKSQ/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKLhSc8Lu6n/
# location.replace('https://www.instagram.com/p/CKLhSc8Lu6n/')
# <class 'list'>
# 62
# https://www.instagram.com/p/CKDaPapBcSA/
# location.replace('https://www.instagram.com/p/CKDaPapBcSA/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJxJYH3h6w2/
# location.replace('https://www.instagram.com/p/CJxJYH3h6w2/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJ3NotIse6R/
# location.replace('https://www.instagram.com/p/CJ3NotIse6R/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CKCFlYIFd35/
# location.replace('https://www.instagram.com/p/CKCFlYIFd35/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJj5k0CF7az/
# location.replace('https://www.instagram.com/p/CJj5k0CF7az/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CKBynDABkQW/
# location.replace('https://www.instagram.com/p/CKBynDABkQW/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJqOLFulNN-/
# location.replace('https://www.instagram.com/p/CJqOLFulNN-/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJ3TeEZpQFi/
# location.replace('https://www.instagram.com/p/CJ3TeEZpQFi/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CKDW0Q5MqCl/
# location.replace('https://www.instagram.com/p/CKDW0Q5MqCl/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKCSl9GFni3/
# location.replace('https://www.instagram.com/p/CKCSl9GFni3/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CKBRB5KMm2c/
# location.replace('https://www.instagram.com/p/CKBRB5KMm2c/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJq235MFHM8/
# location.replace('https://www.instagram.com/p/CJq235MFHM8/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJn6jJslwZh/
# location.replace('https://www.instagram.com/p/CJn6jJslwZh/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CKCthoSFOmK/
# location.replace('https://www.instagram.com/p/CKCthoSFOmK/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJxk_30Hqy6/
# location.replace('https://www.instagram.com/p/CJxk_30Hqy6/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJk-iATF1Co/
# location.replace('https://www.instagram.com/p/CJk-iATF1Co/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJk7OWjli5U/
# location.replace('https://www.instagram.com/p/CJk7OWjli5U/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CKEKaluHEt3/
# location.replace('https://www.instagram.com/p/CKEKaluHEt3/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJiSXRjlJJp/
# location.replace('https://www.instagram.com/p/CJiSXRjlJJp/')
# 버튼없어!!
# <class 'list'>
# 67
# https://www.instagram.com/p/CKKF6NErSHX/
# location.replace('https://www.instagram.com/p/CKKF6NErSHX/')
# <class 'list'>
# 25
# https://www.instagram.com/p/CJjMMJDAscC/
# location.replace('https://www.instagram.com/p/CJjMMJDAscC/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJiUq9JlizT/
# location.replace('https://www.instagram.com/p/CJiUq9JlizT/')
# <class 'list'>
# 39
# https://www.instagram.com/p/CKLlPNGFwzZ/
# location.replace('https://www.instagram.com/p/CKLlPNGFwzZ/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJlWQl9gLo-/
# location.replace('https://www.instagram.com/p/CJlWQl9gLo-/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CJs9N4mgxt5/
# location.replace('https://www.instagram.com/p/CJs9N4mgxt5/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CKBtWJiADvV/
# location.replace('https://www.instagram.com/p/CKBtWJiADvV/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJ3fnw6H1ht/
# location.replace('https://www.instagram.com/p/CJ3fnw6H1ht/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJx9s44BzU1/
# location.replace('https://www.instagram.com/p/CJx9s44BzU1/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CKDS13zrNEP/
# location.replace('https://www.instagram.com/p/CKDS13zrNEP/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJqvRkfJsT2/
# location.replace('https://www.instagram.com/p/CJqvRkfJsT2/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJquK7GFw7z/
# location.replace('https://www.instagram.com/p/CJquK7GFw7z/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJi4sbolqyH/
# location.replace('https://www.instagram.com/p/CJi4sbolqyH/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CJ5GG47n4Af/
# location.replace('https://www.instagram.com/p/CJ5GG47n4Af/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJ0jn5Fh9gM/
# location.replace('https://www.instagram.com/p/CJ0jn5Fh9gM/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ7ugsUpq6B/
# location.replace('https://www.instagram.com/p/CJ7ugsUpq6B/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CKIifLdMiyK/
# location.replace('https://www.instagram.com/p/CKIifLdMiyK/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CJ5wtvoM9l-/
# location.replace('https://www.instagram.com/p/CJ5wtvoM9l-/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CKF32vEFbgA/
# location.replace('https://www.instagram.com/p/CKF32vEFbgA/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJ94fN2Htpi/
# location.replace('https://www.instagram.com/p/CJ94fN2Htpi/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CKBdXrJnxky/
# location.replace('https://www.instagram.com/p/CKBdXrJnxky/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKK8LpcJU1I/
# location.replace('https://www.instagram.com/p/CKK8LpcJU1I/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJ-v73Qneuq/
# location.replace('https://www.instagram.com/p/CJ-v73Qneuq/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CJ9-7JqpuWu/
# location.replace('https://www.instagram.com/p/CJ9-7JqpuWu/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CKGoVq8geTi/
# location.replace('https://www.instagram.com/p/CKGoVq8geTi/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJ8k-YSAZ6x/
# location.replace('https://www.instagram.com/p/CJ8k-YSAZ6x/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJz1fggF3V6/
# location.replace('https://www.instagram.com/p/CJz1fggF3V6/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CKJd3Tsj5al/
# location.replace('https://www.instagram.com/p/CKJd3Tsj5al/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKEXGyllhg_/
# location.replace('https://www.instagram.com/p/CKEXGyllhg_/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJpf_47jVDc/
# location.replace('https://www.instagram.com/p/CJpf_47jVDc/')
# <class 'list'>
# 68
# https://www.instagram.com/p/CJ_peV-l5Yf/
# location.replace('https://www.instagram.com/p/CJ_peV-l5Yf/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CJkPcVRFSQm/
# location.replace('https://www.instagram.com/p/CJkPcVRFSQm/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CKHBENfFReY/
# location.replace('https://www.instagram.com/p/CKHBENfFReY/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJ8ByJkLxMJ/
# location.replace('https://www.instagram.com/p/CJ8ByJkLxMJ/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ1DK0-l7LE/
# location.replace('https://www.instagram.com/p/CJ1DK0-l7LE/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ8K9IWpRDl/
# location.replace('https://www.instagram.com/p/CJ8K9IWpRDl/')
# <class 'list'>
# 38
# https://www.instagram.com/p/CJ5cZJsMqll/
# location.replace('https://www.instagram.com/p/CJ5cZJsMqll/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJwH2G7lUfr/
# location.replace('https://www.instagram.com/p/CJwH2G7lUfr/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJtPnearqiB/
# location.replace('https://www.instagram.com/p/CJtPnearqiB/')
# <class 'list'>
# 63
# https://www.instagram.com/p/CJnXQ-NlNr2/
# location.replace('https://www.instagram.com/p/CJnXQ-NlNr2/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CKJVb8DB9d0/
# location.replace('https://www.instagram.com/p/CKJVb8DB9d0/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CKH1HLUFz-y/
# location.replace('https://www.instagram.com/p/CKH1HLUFz-y/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJvmRaMnSNx/
# location.replace('https://www.instagram.com/p/CJvmRaMnSNx/')
# <class 'list'>
# 139
# https://www.instagram.com/p/CJpO4BBniCW/
# location.replace('https://www.instagram.com/p/CJpO4BBniCW/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJ9MEKZHJA_/
# location.replace('https://www.instagram.com/p/CJ9MEKZHJA_/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJ757TxlVhs/
# location.replace('https://www.instagram.com/p/CJ757TxlVhs/')
# <class 'list'>
# 67
# https://www.instagram.com/p/CKGM8beDOwr/
# location.replace('https://www.instagram.com/p/CKGM8beDOwr/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CJv1q4aj-_B/
# location.replace('https://www.instagram.com/p/CJv1q4aj-_B/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJgYvQeA6pt/
# location.replace('https://www.instagram.com/p/CJgYvQeA6pt/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CKHKloyBUl2/
# location.replace('https://www.instagram.com/p/CKHKloyBUl2/')
# <class 'list'>
# 38
# https://www.instagram.com/p/CJvEv59pWEP/
# location.replace('https://www.instagram.com/p/CJvEv59pWEP/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CKAM4LZn7K0/
# location.replace('https://www.instagram.com/p/CKAM4LZn7K0/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJuzmzxD4Gj/
# location.replace('https://www.instagram.com/p/CJuzmzxD4Gj/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJkWooHJ0QY/
# location.replace('https://www.instagram.com/p/CJkWooHJ0QY/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CKJiwyelyBr/
# location.replace('https://www.instagram.com/p/CKJiwyelyBr/')
# <class 'list'>
# 39
# https://www.instagram.com/p/CJvK5z7FBcr/
# location.replace('https://www.instagram.com/p/CJvK5z7FBcr/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ4tNSdn5M5/
# location.replace('https://www.instagram.com/p/CJ4tNSdn5M5/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJ-Vp9VpqdW/
# location.replace('https://www.instagram.com/p/CJ-Vp9VpqdW/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CJvH4oAFRRn/
# location.replace('https://www.instagram.com/p/CJvH4oAFRRn/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CKFeKUEJZe-/
# location.replace('https://www.instagram.com/p/CKFeKUEJZe-/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CKA2U0uH4yW/
# location.replace('https://www.instagram.com/p/CKA2U0uH4yW/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJ5743xlzQh/
# location.replace('https://www.instagram.com/p/CJ5743xlzQh/')
# 버튼없어!!
# <class 'list'>
# 66
# https://www.instagram.com/p/CJlUPxqlxVo/
# location.replace('https://www.instagram.com/p/CJlUPxqlxVo/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJlu-liliCs/
# location.replace('https://www.instagram.com/p/CJlu-liliCs/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CJ-En-LMu4S/
# location.replace('https://www.instagram.com/p/CJ-En-LMu4S/')
# <class 'list'>
# 23
# https://www.instagram.com/p/CJ_Dn9KDfW9/
# location.replace('https://www.instagram.com/p/CJ_Dn9KDfW9/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CJ_NHlZlu6V/
# location.replace('https://www.instagram.com/p/CJ_NHlZlu6V/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJ40uGIFrhg/
# location.replace('https://www.instagram.com/p/CJ40uGIFrhg/')
# <class 'list'>
# 62
# https://www.instagram.com/p/CJxV2zmlP2K/
# location.replace('https://www.instagram.com/p/CJxV2zmlP2K/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJxPJJhsdEL/
# location.replace('https://www.instagram.com/p/CJxPJJhsdEL/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJm2v3kLVSR/
# location.replace('https://www.instagram.com/p/CJm2v3kLVSR/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJsJv7NF7x4/
# location.replace('https://www.instagram.com/p/CJsJv7NF7x4/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CKLMYiDnpRz/
# location.replace('https://www.instagram.com/p/CKLMYiDnpRz/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJ6URrDlvRc/
# location.replace('https://www.instagram.com/p/CJ6URrDlvRc/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ5zwaMD4pg/
# location.replace('https://www.instagram.com/p/CJ5zwaMD4pg/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJgbtIBHIw5/
# location.replace('https://www.instagram.com/p/CJgbtIBHIw5/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CKIz69BBsTt/
# location.replace('https://www.instagram.com/p/CKIz69BBsTt/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJ7t8dBrVh3/
# location.replace('https://www.instagram.com/p/CJ7t8dBrVh3/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJ5lUQPgdPq/
# location.replace('https://www.instagram.com/p/CJ5lUQPgdPq/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJ6IfqYDbKl/
# location.replace('https://www.instagram.com/p/CJ6IfqYDbKl/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJtH4PKFsJy/
# location.replace('https://www.instagram.com/p/CJtH4PKFsJy/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CJ2UgxtFgxo/
# location.replace('https://www.instagram.com/p/CJ2UgxtFgxo/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJqcbWKBsvR/
# location.replace('https://www.instagram.com/p/CJqcbWKBsvR/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ-0FYOjJeP/
# location.replace('https://www.instagram.com/p/CJ-0FYOjJeP/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKBwULOnPgO/
# location.replace('https://www.instagram.com/p/CKBwULOnPgO/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CKLWSp7MBVL/
# location.replace('https://www.instagram.com/p/CKLWSp7MBVL/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJpQE8Bnmy1/
# location.replace('https://www.instagram.com/p/CJpQE8Bnmy1/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJinY-qBMjz/
# location.replace('https://www.instagram.com/p/CJinY-qBMjz/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CKG59wlhbts/
# location.replace('https://www.instagram.com/p/CKG59wlhbts/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJvagOSnsGm/
# location.replace('https://www.instagram.com/p/CJvagOSnsGm/')
# <class 'list'>
# 23
# https://www.instagram.com/p/CJ9GOxQsdvF/
# location.replace('https://www.instagram.com/p/CJ9GOxQsdvF/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJqLp-pgeGU/
# location.replace('https://www.instagram.com/p/CJqLp-pgeGU/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CKAzTHIjxlI/
# location.replace('https://www.instagram.com/p/CKAzTHIjxlI/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJ8ZcPrn8mp/
# location.replace('https://www.instagram.com/p/CJ8ZcPrn8mp/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJtU-nznY2b/
# location.replace('https://www.instagram.com/p/CJtU-nznY2b/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJrFx9-AABv/
# location.replace('https://www.instagram.com/p/CJrFx9-AABv/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CKEktiSn8zu/
# location.replace('https://www.instagram.com/p/CKEktiSn8zu/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJitAOYlkJK/
# location.replace('https://www.instagram.com/p/CJitAOYlkJK/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CKHCLzgn3YF/
# location.replace('https://www.instagram.com/p/CKHCLzgn3YF/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJ8swiKA2EQ/
# location.replace('https://www.instagram.com/p/CJ8swiKA2EQ/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CJ59BZ-hsma/
# location.replace('https://www.instagram.com/p/CJ59BZ-hsma/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJ2lwUKlzXQ/
# location.replace('https://www.instagram.com/p/CJ2lwUKlzXQ/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ8pIRhlvjc/
# location.replace('https://www.instagram.com/p/CJ8pIRhlvjc/')
# <class 'list'>
# 63
# https://www.instagram.com/p/CKJtgXuFLeZ/
# location.replace('https://www.instagram.com/p/CKJtgXuFLeZ/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKJm7kZD8P-/
# location.replace('https://www.instagram.com/p/CKJm7kZD8P-/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CKLEs_pHC-k/
# location.replace('https://www.instagram.com/p/CKLEs_pHC-k/')
# 버튼없어!!
# <class 'list'>
# 89
# https://www.instagram.com/p/CKExh4Wh--Q/
# location.replace('https://www.instagram.com/p/CKExh4Wh--Q/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CKD33O_HhQf/
# location.replace('https://www.instagram.com/p/CKD33O_HhQf/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CKC_In4M3fR/
# location.replace('https://www.instagram.com/p/CKC_In4M3fR/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CKCMc2UBes2/
# location.replace('https://www.instagram.com/p/CKCMc2UBes2/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJ9rhO1nKXh/
# location.replace('https://www.instagram.com/p/CJ9rhO1nKXh/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKCbtmshkkU/
# location.replace('https://www.instagram.com/p/CKCbtmshkkU/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJ18p5kHITC/
# location.replace('https://www.instagram.com/p/CJ18p5kHITC/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJ02rWaAGtL/
# location.replace('https://www.instagram.com/p/CJ02rWaAGtL/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJvY_RGlHNd/
# location.replace('https://www.instagram.com/p/CJvY_RGlHNd/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJoKqeJhHZ5/
# location.replace('https://www.instagram.com/p/CJoKqeJhHZ5/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CJ9nwMrMyo2/
# location.replace('https://www.instagram.com/p/CJ9nwMrMyo2/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJoPAOWlkjD/
# location.replace('https://www.instagram.com/p/CJoPAOWlkjD/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJl0T9jlRHc/
# location.replace('https://www.instagram.com/p/CJl0T9jlRHc/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJiuJFbL8U9/
# location.replace('https://www.instagram.com/p/CJiuJFbL8U9/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJyP-UvFMon/
# location.replace('https://www.instagram.com/p/CJyP-UvFMon/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKHIaCjM5yS/
# location.replace('https://www.instagram.com/p/CKHIaCjM5yS/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJ-9qwaHOnn/
# location.replace('https://www.instagram.com/p/CJ-9qwaHOnn/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJllCQspiJu/
# location.replace('https://www.instagram.com/p/CJllCQspiJu/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CKF2AkshGa6/
# location.replace('https://www.instagram.com/p/CKF2AkshGa6/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJxVNw-lRmt/
# location.replace('https://www.instagram.com/p/CJxVNw-lRmt/')
# <class 'list'>
# 38
# https://www.instagram.com/p/CJvRixYpjQ7/
# location.replace('https://www.instagram.com/p/CJvRixYpjQ7/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJznvODpVfd/
# location.replace('https://www.instagram.com/p/CJznvODpVfd/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKDzbdFhnN-/
# location.replace('https://www.instagram.com/p/CKDzbdFhnN-/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CKBDB7mDmJG/
# location.replace('https://www.instagram.com/p/CKBDB7mDmJG/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CKD4-qUlqJR/
# location.replace('https://www.instagram.com/p/CKD4-qUlqJR/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJ2odxqFM0N/
# location.replace('https://www.instagram.com/p/CJ2odxqFM0N/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKGpQVmppT1/
# location.replace('https://www.instagram.com/p/CKGpQVmppT1/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJnNbOXHQPi/
# location.replace('https://www.instagram.com/p/CJnNbOXHQPi/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJ33_UklcOX/
# location.replace('https://www.instagram.com/p/CJ33_UklcOX/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJ3tKrWF4LI/
# location.replace('https://www.instagram.com/p/CJ3tKrWF4LI/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJ83sAxpIAA/
# location.replace('https://www.instagram.com/p/CJ83sAxpIAA/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ1CGDjJNZ1/
# location.replace('https://www.instagram.com/p/CJ1CGDjJNZ1/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CJtHmgfAyJj/
# location.replace('https://www.instagram.com/p/CJtHmgfAyJj/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJot9RrjmNW/
# location.replace('https://www.instagram.com/p/CJot9RrjmNW/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CJ2-dyaMxCW/
# location.replace('https://www.instagram.com/p/CJ2-dyaMxCW/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJsnugMnIiZ/
# location.replace('https://www.instagram.com/p/CJsnugMnIiZ/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CKIgYZgJGA3/
# location.replace('https://www.instagram.com/p/CKIgYZgJGA3/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJoAf9KFROR/
# location.replace('https://www.instagram.com/p/CJoAf9KFROR/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJoWeziJJB0/
# location.replace('https://www.instagram.com/p/CJoWeziJJB0/')
# <class 'list'>
# 26
# https://www.instagram.com/p/CJ74tPUnRJc/
# location.replace('https://www.instagram.com/p/CJ74tPUnRJc/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJ8kTrcADux/
# location.replace('https://www.instagram.com/p/CJ8kTrcADux/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJqAoC0BRxI/
# location.replace('https://www.instagram.com/p/CJqAoC0BRxI/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKE9NxeH7Uw/
# location.replace('https://www.instagram.com/p/CKE9NxeH7Uw/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CKHWNteFZ0X/
# location.replace('https://www.instagram.com/p/CKHWNteFZ0X/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ2q4SBFGu6/
# location.replace('https://www.instagram.com/p/CJ2q4SBFGu6/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CKGsKoCLjEW/
# location.replace('https://www.instagram.com/p/CKGsKoCLjEW/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJsCwwhJh-m/
# location.replace('https://www.instagram.com/p/CJsCwwhJh-m/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ-TJ4xH1Cu/
# location.replace('https://www.instagram.com/p/CJ-TJ4xH1Cu/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKJPihisu_k/
# location.replace('https://www.instagram.com/p/CKJPihisu_k/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJvkn1snjlA/
# location.replace('https://www.instagram.com/p/CJvkn1snjlA/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJ53J8cBJ-R/
# location.replace('https://www.instagram.com/p/CJ53J8cBJ-R/')
# <class 'list'>
# 39
# https://www.instagram.com/p/CKHX9YHh4ZZ/
# location.replace('https://www.instagram.com/p/CKHX9YHh4ZZ/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CJv_IaFp00O/
# location.replace('https://www.instagram.com/p/CJv_IaFp00O/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJvegU5Jhu6/
# location.replace('https://www.instagram.com/p/CJvegU5Jhu6/')
# 버튼없어!!
# <class 'list'>
# 76
# https://www.instagram.com/p/CJtSltoBWJU/
# location.replace('https://www.instagram.com/p/CJtSltoBWJU/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJpa4awFb_j/
# location.replace('https://www.instagram.com/p/CJpa4awFb_j/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJu6_QYpvgh/
# location.replace('https://www.instagram.com/p/CJu6_QYpvgh/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CEvElMPlDKL/
# location.replace('https://www.instagram.com/p/CEvElMPlDKL/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJvwBvagiRR/
# location.replace('https://www.instagram.com/p/CJvwBvagiRR/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJmHRYflZ74/
# location.replace('https://www.instagram.com/p/CJmHRYflZ74/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKJS4KrF2wb/
# location.replace('https://www.instagram.com/p/CKJS4KrF2wb/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJRa0eRHTx7/
# location.replace('https://www.instagram.com/p/CJRa0eRHTx7/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CKFirVJlImn/
# location.replace('https://www.instagram.com/p/CKFirVJlImn/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJ7rCHYJaJ3/
# location.replace('https://www.instagram.com/p/CJ7rCHYJaJ3/')
# <class 'list'>
# 39
# https://www.instagram.com/p/CJrZGCzjb5B/
# location.replace('https://www.instagram.com/p/CJrZGCzjb5B/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJ8EJSGH2z5/
# location.replace('https://www.instagram.com/p/CJ8EJSGH2z5/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CKGFikIHbvO/
# location.replace('https://www.instagram.com/p/CKGFikIHbvO/')
# <class 'list'>
# 62
# https://www.instagram.com/p/CJq1-5fFolr/
# location.replace('https://www.instagram.com/p/CJq1-5fFolr/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJh4vtTDT0f/
# location.replace('https://www.instagram.com/p/CJh4vtTDT0f/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CKIosUPr-8r/
# location.replace('https://www.instagram.com/p/CKIosUPr-8r/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJvU4pAnCaA/
# location.replace('https://www.instagram.com/p/CJvU4pAnCaA/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CJ5jlfEnNZU/
# location.replace('https://www.instagram.com/p/CJ5jlfEnNZU/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJ5WDI6lNch/
# location.replace('https://www.instagram.com/p/CJ5WDI6lNch/')
# <class 'list'>
# 79
# https://www.instagram.com/p/CJBIzBVHfS3/
# location.replace('https://www.instagram.com/p/CJBIzBVHfS3/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJ0pzqJlbUN/
# location.replace('https://www.instagram.com/p/CJ0pzqJlbUN/')
# 버튼없어!!
# <class 'list'>
# 70
# https://www.instagram.com/p/CKAmN20AZTW/
# location.replace('https://www.instagram.com/p/CKAmN20AZTW/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJ3HRsRs3OC/
# location.replace('https://www.instagram.com/p/CJ3HRsRs3OC/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJldMHGny4x/
# location.replace('https://www.instagram.com/p/CJldMHGny4x/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJteGOqlVCs/
# location.replace('https://www.instagram.com/p/CJteGOqlVCs/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJ3QFHZFUQ9/
# location.replace('https://www.instagram.com/p/CJ3QFHZFUQ9/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CKBIOO3lu59/
# location.replace('https://www.instagram.com/p/CKBIOO3lu59/')
# <class 'list'>
# 62
# https://www.instagram.com/p/CKJWIoqMQP-/
# location.replace('https://www.instagram.com/p/CKJWIoqMQP-/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJ-1bSjFs2J/
# location.replace('https://www.instagram.com/p/CJ-1bSjFs2J/')
# <class 'list'>
# 25
# https://www.instagram.com/p/CJuU6Q8BT9Q/
# location.replace('https://www.instagram.com/p/CJuU6Q8BT9Q/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKBunHHnuAX/
# location.replace('https://www.instagram.com/p/CKBunHHnuAX/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJi-Qofl1p6/
# location.replace('https://www.instagram.com/p/CJi-Qofl1p6/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CKJxeqNlSz-/
# location.replace('https://www.instagram.com/p/CKJxeqNlSz-/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ7-usAFhld/
# location.replace('https://www.instagram.com/p/CJ7-usAFhld/')
# 버튼없어!!
# <class 'list'>
# 85
# https://www.instagram.com/p/CJ5n0uiHtS_/
# location.replace('https://www.instagram.com/p/CJ5n0uiHtS_/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJifqgHFXBu/
# location.replace('https://www.instagram.com/p/CJifqgHFXBu/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJuTtXqpCEH/
# location.replace('https://www.instagram.com/p/CJuTtXqpCEH/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJgPI8uFcXA/
# location.replace('https://www.instagram.com/p/CJgPI8uFcXA/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJqNCy2luYJ/
# location.replace('https://www.instagram.com/p/CJqNCy2luYJ/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJl5SXRgqYh/
# location.replace('https://www.instagram.com/p/CJl5SXRgqYh/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJyDBWKlieK/
# location.replace('https://www.instagram.com/p/CJyDBWKlieK/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJlTK6iHtbS/
# location.replace('https://www.instagram.com/p/CJlTK6iHtbS/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKDwDRGB03f/
# location.replace('https://www.instagram.com/p/CKDwDRGB03f/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJ5sPHZlmEv/
# location.replace('https://www.instagram.com/p/CJ5sPHZlmEv/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJ0y1Aolhkt/
# location.replace('https://www.instagram.com/p/CJ0y1Aolhkt/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJs-lZwh7gY/
# location.replace('https://www.instagram.com/p/CJs-lZwh7gY/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKLM8kJnQVc/
# location.replace('https://www.instagram.com/p/CKLM8kJnQVc/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJ7OpthLFOY/
# location.replace('https://www.instagram.com/p/CJ7OpthLFOY/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CKDbecgnKI6/
# location.replace('https://www.instagram.com/p/CKDbecgnKI6/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJps7Y6Fnhz/
# location.replace('https://www.instagram.com/p/CJps7Y6Fnhz/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CKBV6GJJV08/
# location.replace('https://www.instagram.com/p/CKBV6GJJV08/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CKJa6mID0mZ/
# location.replace('https://www.instagram.com/p/CKJa6mID0mZ/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJ7QhFepY55/
# location.replace('https://www.instagram.com/p/CJ7QhFepY55/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJ-mBNvhyFa/
# location.replace('https://www.instagram.com/p/CJ-mBNvhyFa/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJmqS13pYRK/
# location.replace('https://www.instagram.com/p/CJmqS13pYRK/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJlLF-qg0uM/
# location.replace('https://www.instagram.com/p/CJlLF-qg0uM/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CJndlXNjRrn/
# location.replace('https://www.instagram.com/p/CJndlXNjRrn/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKLj1HfFXpD/
# location.replace('https://www.instagram.com/p/CKLj1HfFXpD/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJ3rhjjFeMq/
# location.replace('https://www.instagram.com/p/CJ3rhjjFeMq/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJuqOpklAmg/
# location.replace('https://www.instagram.com/p/CJuqOpklAmg/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJgp78xBEFr/
# location.replace('https://www.instagram.com/p/CJgp78xBEFr/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJ0vLGUMME5/
# location.replace('https://www.instagram.com/p/CJ0vLGUMME5/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CKGatCGl5ky/
# location.replace('https://www.instagram.com/p/CKGatCGl5ky/')
# 버튼없어!!
# <class 'list'>
# 66
# https://www.instagram.com/p/CKGutRfA3RT/
# location.replace('https://www.instagram.com/p/CKGutRfA3RT/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJ8l5gsFfVr/
# location.replace('https://www.instagram.com/p/CJ8l5gsFfVr/')
# <class 'list'>
# 79
# https://www.instagram.com/p/CJ8PWCul6Yq/
# location.replace('https://www.instagram.com/p/CJ8PWCul6Yq/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJmng8GBCme/
# location.replace('https://www.instagram.com/p/CJmng8GBCme/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CJk5cjtHeUX/
# location.replace('https://www.instagram.com/p/CJk5cjtHeUX/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CJjyP6LJ0A0/
# location.replace('https://www.instagram.com/p/CJjyP6LJ0A0/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJxOCpXH_59/
# location.replace('https://www.instagram.com/p/CJxOCpXH_59/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJ_arOijWJp/
# location.replace('https://www.instagram.com/p/CJ_arOijWJp/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CKGyFhSJW9T/
# location.replace('https://www.instagram.com/p/CKGyFhSJW9T/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJxZ_dhJPPA/
# location.replace('https://www.instagram.com/p/CJxZ_dhJPPA/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CJi_rLNBIIr/
# location.replace('https://www.instagram.com/p/CJi_rLNBIIr/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJ3MiHHFaUX/
# location.replace('https://www.instagram.com/p/CJ3MiHHFaUX/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJwE61aDxB4/
# location.replace('https://www.instagram.com/p/CJwE61aDxB4/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CKGEpOFsCtC/
# location.replace('https://www.instagram.com/p/CKGEpOFsCtC/')
# 버튼없어!!
# <class 'list'>
# 60
# https://www.instagram.com/p/CJysS_bM-85/
# location.replace('https://www.instagram.com/p/CJysS_bM-85/')
# <class 'list'>
# 28
# https://www.instagram.com/p/CJybaXGJ5bR/
# location.replace('https://www.instagram.com/p/CJybaXGJ5bR/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CKF6HtyBCOp/
# location.replace('https://www.instagram.com/p/CKF6HtyBCOp/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJxthBpFmmk/
# location.replace('https://www.instagram.com/p/CJxthBpFmmk/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJpudtWFhYu/
# location.replace('https://www.instagram.com/p/CJpudtWFhYu/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CKK5fWWsdhN/
# location.replace('https://www.instagram.com/p/CKK5fWWsdhN/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CKGo3jupeTp/
# location.replace('https://www.instagram.com/p/CKGo3jupeTp/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJjG9VoMXLW/
# location.replace('https://www.instagram.com/p/CJjG9VoMXLW/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJ1JZiDlocS/
# location.replace('https://www.instagram.com/p/CJ1JZiDlocS/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJutakUsMUb/
# location.replace('https://www.instagram.com/p/CJutakUsMUb/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJ05xn1leuo/
# location.replace('https://www.instagram.com/p/CJ05xn1leuo/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJiO9TRh0z_/
# location.replace('https://www.instagram.com/p/CJiO9TRh0z_/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJ6FzF-le5j/
# location.replace('https://www.instagram.com/p/CJ6FzF-le5j/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJvsgnHrQ-I/
# location.replace('https://www.instagram.com/p/CJvsgnHrQ-I/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJ1Mve_F2AA/
# location.replace('https://www.instagram.com/p/CJ1Mve_F2AA/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJsy7_EFGsd/
# location.replace('https://www.instagram.com/p/CJsy7_EFGsd/')
# <class 'list'>
# 26
# https://www.instagram.com/p/CKBAqPIDU5L/
# location.replace('https://www.instagram.com/p/CKBAqPIDU5L/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CJuaPgZFssQ/
# location.replace('https://www.instagram.com/p/CJuaPgZFssQ/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CJoy4TdllBl/
# location.replace('https://www.instagram.com/p/CJoy4TdllBl/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJmAkjGlSDc/
# location.replace('https://www.instagram.com/p/CJmAkjGlSDc/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJyvasXs0bN/
# location.replace('https://www.instagram.com/p/CJyvasXs0bN/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CKHvfvKlCH6/
# location.replace('https://www.instagram.com/p/CKHvfvKlCH6/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJ8g1uXD6J3/
# location.replace('https://www.instagram.com/p/CJ8g1uXD6J3/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CKC55ScM9ej/
# location.replace('https://www.instagram.com/p/CKC55ScM9ej/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CJxhcsYBIGb/
# location.replace('https://www.instagram.com/p/CJxhcsYBIGb/')
# <class 'list'>
# 37
# https://www.instagram.com/p/CKJWuG8lKKx/
# location.replace('https://www.instagram.com/p/CKJWuG8lKKx/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CKLikKwjfHB/
# location.replace('https://www.instagram.com/p/CKLikKwjfHB/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CJxnhUaHGdX/
# location.replace('https://www.instagram.com/p/CJxnhUaHGdX/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKBPxLnlOwZ/
# location.replace('https://www.instagram.com/p/CKBPxLnlOwZ/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJof6TVLhcf/
# location.replace('https://www.instagram.com/p/CJof6TVLhcf/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJkpDJHlpbf/
# location.replace('https://www.instagram.com/p/CJkpDJHlpbf/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CKIPwkEh8s4/
# location.replace('https://www.instagram.com/p/CKIPwkEh8s4/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJzjMM8lpQY/
# location.replace('https://www.instagram.com/p/CJzjMM8lpQY/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJlkaWmlsLA/
# location.replace('https://www.instagram.com/p/CJlkaWmlsLA/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJimXkkAOHn/
# location.replace('https://www.instagram.com/p/CJimXkkAOHn/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CJ04a7FFBhC/
# location.replace('https://www.instagram.com/p/CJ04a7FFBhC/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJ1IUxAlGVf/
# location.replace('https://www.instagram.com/p/CJ1IUxAlGVf/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CKCBruwHEZJ/
# location.replace('https://www.instagram.com/p/CKCBruwHEZJ/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJ-LZjzFt56/
# location.replace('https://www.instagram.com/p/CJ-LZjzFt56/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CJ9yYC2pEL0/
# location.replace('https://www.instagram.com/p/CJ9yYC2pEL0/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJ3cMDoM-jC/
# location.replace('https://www.instagram.com/p/CJ3cMDoM-jC/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJqStaahUBT/
# location.replace('https://www.instagram.com/p/CJqStaahUBT/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKFpv1SMQwW/
# location.replace('https://www.instagram.com/p/CKFpv1SMQwW/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJ3As_yM_uo/
# location.replace('https://www.instagram.com/p/CJ3As_yM_uo/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CKEQB0zAk6S/
# location.replace('https://www.instagram.com/p/CKEQB0zAk6S/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJnvfQQlf6A/
# location.replace('https://www.instagram.com/p/CJnvfQQlf6A/')
# 버튼없어!!
# <class 'list'>
# 77
# https://www.instagram.com/p/CJtBci-Fcx-/
# location.replace('https://www.instagram.com/p/CJtBci-Fcx-/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJyTXShpxRj/
# location.replace('https://www.instagram.com/p/CJyTXShpxRj/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJoIDuoFaC7/
# location.replace('https://www.instagram.com/p/CJoIDuoFaC7/')
# <class 'list'>
# 68
# https://www.instagram.com/p/CKAlUGQLkHq/
# location.replace('https://www.instagram.com/p/CKAlUGQLkHq/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKGrbKrp_G0/
# location.replace('https://www.instagram.com/p/CKGrbKrp_G0/')
# <class 'list'>
# 46
# https://www.instagram.com/p/CKC92fdghB5/
# location.replace('https://www.instagram.com/p/CKC92fdghB5/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJ8AEiIlLwV/
# location.replace('https://www.instagram.com/p/CJ8AEiIlLwV/')
# 버튼없어!!
# <class 'list'>
# 120
# https://www.instagram.com/p/CJtOM_DgHU2/
# location.replace('https://www.instagram.com/p/CJtOM_DgHU2/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJvas8Sjzok/
# location.replace('https://www.instagram.com/p/CJvas8Sjzok/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJ3SwauFiik/
# location.replace('https://www.instagram.com/p/CJ3SwauFiik/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJ53y5Plb8i/
# location.replace('https://www.instagram.com/p/CJ53y5Plb8i/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJ5PpjOHBt1/
# location.replace('https://www.instagram.com/p/CJ5PpjOHBt1/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJlD0VLFvRC/
# location.replace('https://www.instagram.com/p/CJlD0VLFvRC/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJe0E2BpEwK/
# location.replace('https://www.instagram.com/p/CJe0E2BpEwK/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJ8wbgdFBoB/
# location.replace('https://www.instagram.com/p/CJ8wbgdFBoB/')
# <class 'list'>
# 28
# https://www.instagram.com/p/CKB9YC4F4DV/
# location.replace('https://www.instagram.com/p/CKB9YC4F4DV/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJmyULcFV8Y/
# location.replace('https://www.instagram.com/p/CJmyULcFV8Y/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKEni0VBWQo/
# location.replace('https://www.instagram.com/p/CKEni0VBWQo/')
# <class 'list'>
# 57
# ...
# location.replace('https://www.instagram.com/p/CJsMSj-B9mf/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJ8WMOhH3wa/
# location.replace('https://www.instagram.com/p/CJ8WMOhH3wa/')
# 버튼없어!!
# <class 'list'>
# 67
# https://www.instagram.com/p/CJnxePAgqd1/
# location.replace('https://www.instagram.com/p/CJnxePAgqd1/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJnLIQ9la7t/
# location.replace('https://www.instagram.com/p/CJnLIQ9la7t/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CKHGWDShVUT/
# location.replace('https://www.instagram.com/p/CKHGWDShVUT/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJ6b_qqFp6P/
# location.replace('https://www.instagram.com/p/CJ6b_qqFp6P/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJx27sMnoac/
# location.replace('https://www.instagram.com/p/CJx27sMnoac/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJxP_w6MTNN/
# location.replace('https://www.instagram.com/p/CJxP_w6MTNN/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CKG3zFEjoHw/
# location.replace('https://www.instagram.com/p/CKG3zFEjoHw/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CJqbidXpJML/
# location.replace('https://www.instagram.com/p/CJqbidXpJML/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CKKQtHNBNE1/
# location.replace('https://www.instagram.com/p/CKKQtHNBNE1/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJt4ZHGDN0k/
# location.replace('https://www.instagram.com/p/CJt4ZHGDN0k/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CKAbCSjhA-R/
# location.replace('https://www.instagram.com/p/CKAbCSjhA-R/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CKIrBj3JwvN/
# location.replace('https://www.instagram.com/p/CKIrBj3JwvN/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CKKCj2JF-5Y/
# location.replace('https://www.instagram.com/p/CKKCj2JF-5Y/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJhtauglr2k/
# location.replace('https://www.instagram.com/p/CJhtauglr2k/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJjR1VZls_w/
# location.replace('https://www.instagram.com/p/CJjR1VZls_w/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJ3JXrHDeTe/
# location.replace('https://www.instagram.com/p/CJ3JXrHDeTe/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJmwlj_pSWw/
# location.replace('https://www.instagram.com/p/CJmwlj_pSWw/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJj-KsdB8a2/
# location.replace('https://www.instagram.com/p/CJj-KsdB8a2/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CKLPSKBpneP/
# location.replace('https://www.instagram.com/p/CKLPSKBpneP/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CKK1qhLnuve/
# location.replace('https://www.instagram.com/p/CKK1qhLnuve/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CKJ026klFxA/
# location.replace('https://www.instagram.com/p/CKJ026klFxA/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CKB6OoeFcqk/
# location.replace('https://www.instagram.com/p/CKB6OoeFcqk/')
# <class 'list'>
# 29
# https://www.instagram.com/p/CJyX3munpEn/
# location.replace('https://www.instagram.com/p/CJyX3munpEn/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJyAKtvLaIc/
# location.replace('https://www.instagram.com/p/CJyAKtvLaIc/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CKEg3g8Mgpu/
# location.replace('https://www.instagram.com/p/CKEg3g8Mgpu/')
# <class 'list'>
# 41
# https://www.instagram.com/p/CJ0XOsjFmhl/
# location.replace('https://www.instagram.com/p/CJ0XOsjFmhl/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CKA5hlZHR0m/
# location.replace('https://www.instagram.com/p/CKA5hlZHR0m/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJrtO96n6Mv/
# location.replace('https://www.instagram.com/p/CJrtO96n6Mv/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJ30uqvl2Zi/
# location.replace('https://www.instagram.com/p/CJ30uqvl2Zi/')
# <class 'list'>
# 59
# https://www.instagram.com/p/CJyMdmfFEzG/
# location.replace('https://www.instagram.com/p/CJyMdmfFEzG/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJpz5-ILTlx/
# location.replace('https://www.instagram.com/p/CJpz5-ILTlx/')
# <class 'list'>
# 38
# https://www.instagram.com/p/CJscDJwlRla/
# location.replace('https://www.instagram.com/p/CJscDJwlRla/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJzZVWSlDzS/
# location.replace('https://www.instagram.com/p/CJzZVWSlDzS/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJmzpsYFspE/
# location.replace('https://www.instagram.com/p/CJmzpsYFspE/')
# <class 'list'>
# 38
# https://www.instagram.com/p/CJs7dfgAsS2/
# location.replace('https://www.instagram.com/p/CJs7dfgAsS2/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJv32yqp0IA/
# location.replace('https://www.instagram.com/p/CJv32yqp0IA/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJkFh9OhAD4/
# location.replace('https://www.instagram.com/p/CJkFh9OhAD4/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CKLRwjZHGH1/
# location.replace('https://www.instagram.com/p/CKLRwjZHGH1/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CKKeoVFHdus/
# location.replace('https://www.instagram.com/p/CKKeoVFHdus/')
# 버튼없어!!
# <class 'list'>
# 73
# https://www.instagram.com/p/CJ8e4cYlbKb/
# location.replace('https://www.instagram.com/p/CJ8e4cYlbKb/')
# <class 'list'>
# 39
# https://www.instagram.com/p/CJ3ifDdFBwO/
# location.replace('https://www.instagram.com/p/CJ3ifDdFBwO/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJqQQ93haPE/
# location.replace('https://www.instagram.com/p/CJqQQ93haPE/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJ0shyfJxFe/
# location.replace('https://www.instagram.com/p/CJ0shyfJxFe/')
# <class 'list'>
# 43
# https://www.instagram.com/p/CJqSL27h6C5/
# location.replace('https://www.instagram.com/p/CJqSL27h6C5/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CJvLXi9ncpS/
# location.replace('https://www.instagram.com/p/CJvLXi9ncpS/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CKK9O6VBShx/
# location.replace('https://www.instagram.com/p/CKK9O6VBShx/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJlaOQFgleN/
# location.replace('https://www.instagram.com/p/CJlaOQFgleN/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJtTwJ0FuTA/
# location.replace('https://www.instagram.com/p/CJtTwJ0FuTA/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CKCzobQHhii/
# location.replace('https://www.instagram.com/p/CKCzobQHhii/')
# <class 'list'>
# 34
# https://www.instagram.com/p/CKFSw0kgfTl/
# location.replace('https://www.instagram.com/p/CKFSw0kgfTl/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CJx6dKGljPZ/
# location.replace('https://www.instagram.com/p/CJx6dKGljPZ/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJ-4LX0lEGh/
# location.replace('https://www.instagram.com/p/CJ-4LX0lEGh/')
# 버튼없어!!
# <class 'list'>
# 54
# https://www.instagram.com/p/CJrlYBygPyd/
# location.replace('https://www.instagram.com/p/CJrlYBygPyd/')
# <class 'list'>
# 28
# https://www.instagram.com/p/CJqUBmGF5Mk/
# location.replace('https://www.instagram.com/p/CJqUBmGF5Mk/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJnh_piB1ev/
# location.replace('https://www.instagram.com/p/CJnh_piB1ev/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJkJffws5D_/
# location.replace('https://www.instagram.com/p/CJkJffws5D_/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJy2BTVAeLm/
# location.replace('https://www.instagram.com/p/CJy2BTVAeLm/')
# <class 'list'>
# 47
# https://www.instagram.com/p/CKI4PNEl60k/
# location.replace('https://www.instagram.com/p/CKI4PNEl60k/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJ7jiMvJLSj/
# location.replace('https://www.instagram.com/p/CJ7jiMvJLSj/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKFboYyn7wU/
# location.replace('https://www.instagram.com/p/CKFboYyn7wU/')
# <class 'list'>
# 21
# https://www.instagram.com/p/CKI1HFkhhuk/
# location.replace('https://www.instagram.com/p/CKI1HFkhhuk/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJ7Z-PdMRRi/
# location.replace('https://www.instagram.com/p/CJ7Z-PdMRRi/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJwUm7bl542/
# location.replace('https://www.instagram.com/p/CJwUm7bl542/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJ_K_b-lzJ2/
# location.replace('https://www.instagram.com/p/CJ_K_b-lzJ2/')
# <class 'list'>
# 19
# https://www.instagram.com/p/CJ1T6sWHnri/
# location.replace('https://www.instagram.com/p/CJ1T6sWHnri/')
# <class 'list'>
# 28
# https://www.instagram.com/p/CJ09ZQinKJX/
# location.replace('https://www.instagram.com/p/CJ09ZQinKJX/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJt08M7hQkw/
# location.replace('https://www.instagram.com/p/CJt08M7hQkw/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CIs5JFmDDNw/
# location.replace('https://www.instagram.com/p/CIs5JFmDDNw/')
# <class 'list'>
# 28
# https://www.instagram.com/p/CKJ9JVfF369/
# location.replace('https://www.instagram.com/p/CKJ9JVfF369/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJxX3gxBVOG/
# location.replace('https://www.instagram.com/p/CJxX3gxBVOG/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJtMSuOAKG8/
# location.replace('https://www.instagram.com/p/CJtMSuOAKG8/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJoaM-aF5wk/
# location.replace('https://www.instagram.com/p/CJoaM-aF5wk/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJn2n0bFrBg/
# location.replace('https://www.instagram.com/p/CJn2n0bFrBg/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKDo_yojVD3/
# location.replace('https://www.instagram.com/p/CKDo_yojVD3/')
# <class 'list'>
# 45
# https://www.instagram.com/p/CJliy3XsNCZ/
# location.replace('https://www.instagram.com/p/CJliy3XsNCZ/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CJ7z2tHB_TZ/
# location.replace('https://www.instagram.com/p/CJ7z2tHB_TZ/')
# <class 'list'>
# 60
# https://www.instagram.com/p/CJyWAZ7lriU/
# location.replace('https://www.instagram.com/p/CJyWAZ7lriU/')
# <class 'list'>
# 21
# https://www.instagram.com/p/CJkkKdNpDWl/
# location.replace('https://www.instagram.com/p/CJkkKdNpDWl/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJtpA2IDLi9/
# location.replace('https://www.instagram.com/p/CJtpA2IDLi9/')
# <class 'list'>
# 28
# https://www.instagram.com/p/CJrD911Hvyo/
# location.replace('https://www.instagram.com/p/CJrD911Hvyo/')
# <class 'list'>
# 66
# https://www.instagram.com/p/CJ8rypXDSFv/
# location.replace('https://www.instagram.com/p/CJ8rypXDSFv/')
# <class 'list'>
# 44
# https://www.instagram.com/p/CJ-OKvXHeyq/
# location.replace('https://www.instagram.com/p/CJ-OKvXHeyq/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJ8QYKfnKMX/
# location.replace('https://www.instagram.com/p/CJ8QYKfnKMX/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJ3LdMJB3uP/
# location.replace('https://www.instagram.com/p/CJ3LdMJB3uP/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJsVo0oAU2K/
# location.replace('https://www.instagram.com/p/CJsVo0oAU2K/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CKFoLnpJG9h/
# location.replace('https://www.instagram.com/p/CKFoLnpJG9h/')
# <class 'list'>
# 40
# https://www.instagram.com/p/CJvDy4sHvFP/
# location.replace('https://www.instagram.com/p/CJvDy4sHvFP/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJs8Me5lTCd/
# location.replace('https://www.instagram.com/p/CJs8Me5lTCd/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CJvfN7Ig4iy/
# location.replace('https://www.instagram.com/p/CJvfN7Ig4iy/')
# <class 'list'>
# 42
# https://www.instagram.com/p/CJvy43gBxUL/
# location.replace('https://www.instagram.com/p/CJvy43gBxUL/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CKFrLNdsnHI/
# location.replace('https://www.instagram.com/p/CKFrLNdsnHI/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJqR9VKh-D5/
# location.replace('https://www.instagram.com/p/CJqR9VKh-D5/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKGxf9ih-hJ/
# location.replace('https://www.instagram.com/p/CKGxf9ih-hJ/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CJz23lkFlrg/
# location.replace('https://www.instagram.com/p/CJz23lkFlrg/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJke0UxJRuA/
# location.replace('https://www.instagram.com/p/CJke0UxJRuA/')
# <class 'list'>
# 31
# https://www.instagram.com/p/CJvw-f0ne3Q/
# location.replace('https://www.instagram.com/p/CJvw-f0ne3Q/')
# <class 'list'>
# 62
# https://www.instagram.com/p/CJxd8SOl8LY/
# location.replace('https://www.instagram.com/p/CJxd8SOl8LY/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJkoBDBFO-G/
# location.replace('https://www.instagram.com/p/CJkoBDBFO-G/')
# <class 'list'>
# 48
# https://www.instagram.com/p/CKD2f9Vrkjf/
# location.replace('https://www.instagram.com/p/CKD2f9Vrkjf/')
# <class 'list'>
# 66
# https://www.instagram.com/p/CJ7X-kOFMiq/
# location.replace('https://www.instagram.com/p/CJ7X-kOFMiq/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJpGfNuB_w7/
# location.replace('https://www.instagram.com/p/CJpGfNuB_w7/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJlxEA_BKgM/
# location.replace('https://www.instagram.com/p/CJlxEA_BKgM/')
# <class 'list'>
# 50
# https://www.instagram.com/p/CKD9CRclA7p/
# location.replace('https://www.instagram.com/p/CKD9CRclA7p/')
# <class 'list'>
# 36
# https://www.instagram.com/p/CKIhlqchpyG/
# location.replace('https://www.instagram.com/p/CKIhlqchpyG/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJld2mkBAdf/
# location.replace('https://www.instagram.com/p/CJld2mkBAdf/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJ0-QLslwov/
# location.replace('https://www.instagram.com/p/CJ0-QLslwov/')
# <class 'list'>
# 58
# https://www.instagram.com/p/CJhHISmHB78/
# location.replace('https://www.instagram.com/p/CJhHISmHB78/')
# <class 'list'>
# 66
# https://www.instagram.com/p/CJqSVoLn3Vc/
# location.replace('https://www.instagram.com/p/CJqSVoLn3Vc/')
# <class 'list'>
# 53
# https://www.instagram.com/p/CJ3Dfr3Fu9F/
# location.replace('https://www.instagram.com/p/CJ3Dfr3Fu9F/')
# 버튼없어!!
# <class 'list'>
# 93
# https://www.instagram.com/p/CJjXbAZLjOk/
# location.replace('https://www.instagram.com/p/CJjXbAZLjOk/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJioVAmLWF3/
# location.replace('https://www.instagram.com/p/CJioVAmLWF3/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CKD6-BuJ_38/
# location.replace('https://www.instagram.com/p/CKD6-BuJ_38/')
# <class 'list'>
# 33
# https://www.instagram.com/p/CJlrSDIlb7l/
# location.replace('https://www.instagram.com/p/CJlrSDIlb7l/')
# <class 'list'>
# 35
# https://www.instagram.com/p/CJlQD8DBmyt/
# location.replace('https://www.instagram.com/p/CJlQD8DBmyt/')
# <class 'list'>
# 32
# https://www.instagram.com/p/CJk8erQFTT9/
# location.replace('https://www.instagram.com/p/CJk8erQFTT9/')
# <class 'list'>
# 70
# https://www.instagram.com/p/CKB1dqXDHHo/
# location.replace('https://www.instagram.com/p/CKB1dqXDHHo/')
# <class 'list'>
# 61
# https://www.instagram.com/p/CKKVsNRHDBf/
# location.replace('https://www.instagram.com/p/CKKVsNRHDBf/')
# <class 'list'>
# 52
# https://www.instagram.com/p/CJkmiEWl0Ll/
# location.replace('https://www.instagram.com/p/CJkmiEWl0Ll/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CJw91L5F98W/
# location.replace('https://www.instagram.com/p/CJw91L5F98W/')
# 버튼없어!!
# <class 'list'>
# 70
# https://www.instagram.com/p/CKI73VhFGtW/
# location.replace('https://www.instagram.com/p/CKI73VhFGtW/')
# <class 'list'>
# 49
# https://www.instagram.com/p/CJyaC46l2jD/
# location.replace('https://www.instagram.com/p/CJyaC46l2jD/')
# <class 'list'>
# 16
# https://www.instagram.com/p/CKJN_X-BHjt/
# location.replace('https://www.instagram.com/p/CKJN_X-BHjt/')
# <class 'list'>
# 27
# https://www.instagram.com/p/CJueGfkMgOu/
# location.replace('https://www.instagram.com/p/CJueGfkMgOu/')
# 버튼없어!!
# <class 'list'>
# 72
# https://www.instagram.com/p/CJtWEall78N/
# location.replace('https://www.instagram.com/p/CJtWEall78N/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CKAVM-0lRDO/
# location.replace('https://www.instagram.com/p/CKAVM-0lRDO/')
# <class 'list'>
# 54
# https://www.instagram.com/p/CJnJlb3gwHm/
# location.replace('https://www.instagram.com/p/CJnJlb3gwHm/')
# <class 'list'>
# 51
# https://www.instagram.com/p/CJk9kLMJZkL/
# location.replace('https://www.instagram.com/p/CJk9kLMJZkL/')
# <class 'list'>
# 30
# https://www.instagram.com/p/CKEG-qUD1NH/
# location.replace('https://www.instagram.com/p/CKEG-qUD1NH/')
# <class 'list'>
# 56
# https://www.instagram.com/p/CJ9a2NEBsEO/
# location.replace('https://www.instagram.com/p/CJ9a2NEBsEO/')
# <class 'list'>
# 55
# https://www.instagram.com/p/CJnQ0WIs5Ap/
# location.replace('https://www.instagram.com/p/CJnQ0WIs5Ap/')
# <class 'list'>
# 57
# https://www.instagram.com/p/CKG0xHUrqDu/
# location.replace('https://www.instagram.com/p/CKG0xHUrqDu/')
# <class 'list'>
# 32
# 완벽 정상 작동
